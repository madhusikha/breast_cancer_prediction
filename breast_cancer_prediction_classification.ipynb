# %% [markdown]
# # Dataset: Wisconsin Dataset downloaded from
#
# https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams["figure.dpi"] = 200

# %%
df = pd.read_csv('data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.head().transpose()
# Out:
#                                 0         1         2         3         4
# id                         842302    842517  84300903  84348301  84358402
# diagnosis                       M         M         M         M         M
# radius_mean                 17.99     20.57     19.69     11.42     20.29
# texture_mean                10.38     17.77     21.25     20.38     14.34
# perimeter_mean              122.8     132.9     130.0     77.58     135.1
# area_mean                  1001.0    1326.0    1203.0     386.1    1297.0
# smoothness_mean            0.1184   0.08474    0.1096    0.1425    0.1003
# compactness_mean           0.2776   0.07864    0.1599    0.2839    0.1328
# concavity_mean             0.3001    0.0869    0.1974    0.2414     0.198
# concave points_mean        0.1471   0.07017    0.1279    0.1052    0.1043
# symmetry_mean              0.2419    0.1812    0.2069    0.2597    0.1809
# fractal_dimension_mean    0.07871   0.05667   0.05999   0.09744   0.05883
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# aprt from 'Unnamed: 32' column, the dataset has no NaN values in any feature

# %%
# Dropping two columns:
# 1. id-- because while training, features of this kind (like name, id, etcc) doesnot carry any info
# 2. Unname:32 -- because it has all NaN values

# %%
df = df.drop(['id','Unnamed: 32'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
# except 'diagnosis' column, all the remaining are Numerical columns

# %%
# lets find different categories in 'diagnosis' column

# %%
df['diagnosis'].nunique()
# Out:
# 2

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
# there are two categories, lets replace 'B' by 0 and 'M' by 1

# %%
def my_func(c):
    if (c=='B'):
        return 0
    else:
        return 1

df['diagnosis'] = list(map(my_func, df['diagnosis']))    # replacing 'B' by 0 and 'M' by 1 using map()

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
# lets calculate the correlation heatmap

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
# lets find the correlations with 'doagnosis' columns

df.corr()['diagnosis'].sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# ...

# %% [markdown]
# 1. first do simple logistic regression
#
# some input features are also highly correlated among themselves--
#
# 2. use different regularizations with Logistic regression (GridSearchCV)
#
# 3. use PCA with Logistic Regression
#
# https://dwbi1.wordpress.com/2021/04/16/logistic-regression-with-pca-in-python/
#
# 4. RFE- recursive feature elimination with logistic regression
#
# try these two then other methods (like SVM, decision trees, random forests, boosting, etc.)

# %%
# lets separate input features and target columns

X = df.drop('diagnosis',axis=1)
y = df['diagnosis']

# %%
X.shape
# Out:
# (569, 30)

# %%
# train test split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#  there are no null values in the dataset now

# lets scale the data using MinMax scaler

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# # when u open afresh, run all cells above.. some models take lot of time to run.
# # from here (cells downside) run only required cells

# %% [markdown]
# # 1. logistic regression- baseline model

# %%
from sklearn.linear_model import LogisticRegression

logit_reg_baseline_model = LogisticRegression()

logit_reg_baseline_model.fit(scaled_X_train, y_train)

y_pred_logit_reg_blm = logit_reg_baseline_model.predict(scaled_X_test)   # blm- baselinemodel

# %%
from sklearn.metrics import r2_score, accuracy_score

# %%
r2_logit_blm = r2_score(y_test, y_pred_logit_reg_blm)
r2_logit_blm
# Out:
# 0.8492063492063492

# %%
acc_score_logit_blm = accuracy_score(y_test, y_pred_logit_reg_blm)
acc_score_logit_blm
# Out:
# 0.9649122807017544

# %%
# function to calculate performance metrics
def perf_metrics(y_pred):
    r2 = r2_score(y_test, y_pred)
    acc_score = accuracy_score(y_test, y_pred)
    return r2, acc_score

# %% [markdown]
# with **simple logistic regression** and **using all the features**, achieved an **R2 score of 0.85** and **accuracy score of 0.965**.

# %% [markdown]
# # 2. Logistic regression with GridSearchCV

# %%
# in the baseline model we have used all default parameters, wherein the regularization used was 'L2'.

# now lets try all parameters with different values using GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

logit_reg_baseline_model = LogisticRegression(solver='saga',max_iter=5000)

# %%
# param_grid

penalty = ['l1','l2','elasticnet']

l1_ratio = np.linspace(0,1,10)

C = np.logspace(0,20,10)   # documentation suggests C to be log values

param_grid = {'penalty':penalty, 'l1_ratio':l1_ratio, 'C':C}

# %%
from sklearn.model_selection import GridSearchCV

grid_logit = GridSearchCV(logit_reg_baseline_model, param_grid = param_grid, cv=5, scoring='f1',verbose=0)

grid_logit.fit(scaled_X_train, y_train);
# Out:
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# ...

# %%
grid_logit.best_estimator_
# Out:
# LogisticRegression(C=166.81005372000593, l1_ratio=0.0, max_iter=5000,
#                    penalty='l1', solver='saga')

# %%
grid_logit.best_params_
# Out:
# {'C': 166.81005372000593, 'l1_ratio': 0.0, 'penalty': 'l1'}

# %%
grid_logit.best_score_
# Out:
# 0.9618553743159237

# %%
best_logit_grid = LogisticRegression(C=166.81005372000593, l1_ratio=0.0, max_iter=5000,
                   penalty='l1', solver='saga')

best_logit_grid.fit(scaled_X_train, y_train)

y_pred_best_logit_grid = best_logit_grid.predict(scaled_X_test)

r2_best_logit, acc_score_best_logit = perf_metrics(y_pred_best_logit_grid)
# Out:
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(

# %%
r2_best_logit
# Out:
# 0.8743386243386243

# %%
acc_score_best_logit
# Out:
# 0.9707602339181286

# %%
# predict
y_pred_logit_grid = grid_logit.predict(scaled_X_test)

# performance metrics
r2_logit_grid, acc_score_logit_grid = perf_metrics(y_pred_logit_grid)

# %%
r2_logit_grid
# Out:
# 0.8743386243386243

# %%
acc_score_logit_grid
# Out:
# 0.9707602339181286

# %%
# SIDENOTE, IMPORTANT: NO NEED OF FITTING MODEL AGAIN AFTER GRIDSEARCHCV
#we got same values as fitting the model with best parameters, which means ..
# we need not to fit the model after GridSearchCV

# %% [markdown]
# **logistic regression** with **GridSearchCV** and **using all the input features**, we got an **R2 score of 0.8743386243386243** and **accuracy score of 0.9707602339181286**.
#
# **Observation: GridSearchCV + logistic regression is better than simple logistic regression**

# %% [markdown]
# # PCA with Logistic Regression

# %% [markdown]
# https://www.statology.org/principal-components-regression-in-python/
#
# https://dwbi1.wordpress.com/2021/04/16/logistic-regression-with-pca-in-python/
#
# https://dwbi1.wordpress.com/2021/04/15/linear-regression-in-python/
#
# https://www.youtube.com/watch?v=pcZ4YlvhSKU
#
# https://kgptalkie.com/recursive-feature-elimination-rfe-by-using-tree-based-and-gradient-based-estimators-machine-learning-kgp-talkie/

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.90)

# %%
# transforming training and testing data using PCA

X_train_pca = pca.fit_transform(scaled_X_train)

X_test_pca = pca.transform(scaled_X_test)

# %%
X_train_pca.shape

# 30 features in input X are brought down to 6 features after performing PCA
# Out:
# (398, 6)

# %% [markdown]
# # now fitting Logistic Regression on the PCA data

# %% [markdown]
# # 3. logistic regression with PCA data- baseline model

# %%
from sklearn.linear_model import LogisticRegression

pca_logit_reg_base = LogisticRegression()

pca_logit_reg_base.fit(X_train_pca, y_train)

y_pred_pca_logit_reg = pca_logit_reg_base.predict(X_test_pca)   # blm- baselinemodel

r2_pca_logit_base, acc_score_pca_logit_base = perf_metrics(y_pred_pca_logit_reg)

print(r2_pca_logit_base, acc_score_pca_logit_base)
# Out:
# 0.8743386243386243 0.9707602339181286

# %%
pca.explained_variance_ratio_
# Out:
# array([0.50627899, 0.18388545, 0.07821564, 0.06284622, 0.04124941,
#        0.0337878 ])

# %%
pca.n_components_
# Out:
# 6

# %% [markdown]
# Observations from Logistic Regression with PCA data:
#
# pca = PCA(n_components=0.90)
#
# This means we are informing to select number of features such that the total variance is 90%

# %%
# lets plot % variance vs number of components and r2 score and accuracy

# %%
n_components = np.arange(0.8,1,0.01)
n_components
# Out:
# array([0.8 , 0.81, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9 ,
#        0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99])

# %%
n_components = np.arange(0.8,1,0.01)
r2=[]
acc=[]
number_components = []
for n in range(len(n_components)):
    pca = PCA(n_components=n_components[n])
    X_train_pca = pca.fit_transform(scaled_X_train)
    X_test_pca = pca.transform(scaled_X_test)
    pca_logit_reg_base = LogisticRegression()

    pca_logit_reg_base.fit(X_train_pca, y_train)

    y_pred_pca_logit_reg = pca_logit_reg_base.predict(X_test_pca)   # blm- baselinemodel

    r2_pca_logit_base, acc_score_pca_logit_base = perf_metrics(y_pred_pca_logit_reg)
    number_components.append(pca.n_components_)
    r2.append(r2_pca_logit_base)
    acc.append(acc_score_pca_logit_base)

    print(f'%variance: {round(n_components[n]*100,2)}, Number of components: {pca.n_components_}, R2 score: {round(r2_pca_logit_base,4)}, Accuracy: {round(acc_score_pca_logit_base,4)}')
# Out:
# %variance: 80.0, Number of components: 4, R2 score: 0.8241, Accuracy: 0.9591
# %variance: 81.0, Number of components: 4, R2 score: 0.8241, Accuracy: 0.9591
# %variance: 82.0, Number of components: 4, R2 score: 0.8241, Accuracy: 0.9591
# %variance: 83.0, Number of components: 4, R2 score: 0.8241, Accuracy: 0.9591
# %variance: 84.0, Number of components: 5, R2 score: 0.8743, Accuracy: 0.9708
# %variance: 85.0, Number of components: 5, R2 score: 0.8743, Accuracy: 0.9708
# %variance: 86.0, Number of components: 5, R2 score: 0.8743, Accuracy: 0.9708
# %variance: 87.0, Number of components: 5, R2 score: 0.8743, Accuracy: 0.9708
# %variance: 88.0, Number of components: 6, R2 score: 0.8743, Accuracy: 0.9708
# %variance: 89.0, Number of components: 6, R2 score: 0.8743, Accuracy: 0.9708
# %variance: 90.0, Number of components: 6, R2 score: 0.8743, Accuracy: 0.9708
# %variance: 91.0, Number of components: 7, R2 score: 0.8492, Accuracy: 0.9649
# ...

# %% [markdown]
# From the above results, we can observe that the maximum R2 score is 0.8743 and Accuracy is 0.9708 for number of components of 5 and 6 (i.e., % variance of 84% to 90%). Beyond which the performance again drops slightly.
#
# These metrics values are coinciding with Logistic Regression GridSearchCV values (Why?).

# %%
plt.plot(number_components,acc)
plt.plot(number_components,r2)
plt.plot(number_components,n_components)

# %% [markdown]
# # 4. logistic regression with PCA data- GridSearchCV

# %%
# from above, the optimum value is for % of variance is 90%
# pca = PCA(n_components=0.9)
# # X_train_pca = pca.fit_transform(scaled_X_train)
# X_test_pca = pca.transform(scaled_X_test)

# %%
from sklearn.linear_model import LogisticRegression

logit_reg_baseline_model = LogisticRegression(solver='saga',max_iter=5000)

# param_grid

penalty = ['l1','l2','elasticnet']

l1_ratio = np.linspace(0,1,10)

C = np.logspace(0,20,10)   # documentation suggests C to be log values

param_grid = {'penalty':penalty, 'l1_ratio':l1_ratio, 'C':C}

# %%
from sklearn.model_selection import GridSearchCV

grid_pca_logit = GridSearchCV(logit_reg_baseline_model, param_grid = param_grid, cv=5, scoring='f1',verbose=0)

grid_pca_logit.fit(X_train_pca, y_train);
# Out:
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# ...

# %%
grid_pca_logit.best_params_
# Out:
# {'C': 166.81005372000593, 'l1_ratio': 0.0, 'penalty': 'l2'}

# %%
grid_pca_logit.best_estimator_
# Out:
# LogisticRegression(C=166.81005372000593, l1_ratio=0.0, max_iter=5000,
#                    solver='saga')

# %%
y_pred_best_pca_logit_grid = grid_pca_logit.predict(X_test_pca)

r2_best_pca_logit, acc_score_best_pca_logit = perf_metrics(y_pred_best_pca_logit_grid)

# %%
r2_best_pca_logit
# Out:
# 0.9497354497354498

# %%
acc_score_best_pca_logit
# Out:
# 0.9883040935672515

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred_best_pca_logit_grid)
# Out:
# array([[107,   1],
#        [  1,  62]])

# %%
plot_confusion_matrix(grid_pca_logit, X_test_pca, y_test);
# Out:
# /home/smadhu/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test, y_pred_best_pca_logit_grid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       108
#            1       0.98      0.98      0.98        63
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %% [markdown]
# # 5. Recursive Feature Extraction

# %%
log_model_for_rfe = LogisticRegression(C=166.81005372000593, l1_ratio=0.0, max_iter=5000,
                   penalty='l1', solver='saga')  # this model parameters are selected from gridsearchcv

# %%
from sklearn.feature_selection import RFE
sel = RFE(log_model_for_rfe, n_features_to_select = 6)
sel.fit(X_train, y_train)
# Out:
# C:\Users\gsikha\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# C:\Users\gsikha\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# C:\Users\gsikha\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# C:\Users\gsikha\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# ...

# %%
sel.get_support()
# Out:
# array([False, False,  True,  True, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False,  True, False,  True,  True, False, False, False,
#        False, False, False])

# %%
features = X_train.columns[sel.get_support()]
features
# Out:
# Index(['perimeter_mean', 'area_mean', 'area_se', 'radius_worst',
#        'perimeter_worst', 'area_worst'],
#       dtype='object')

# %%
X_train_rfc = sel.transform(X_train)
X_test_rfc = sel.transform(X_test)

# %%
def run_logistic(X_train, X_test, y_train, y_test):
    clf = LogisticRegression(C=166.81005372000593, l1_ratio=0.0, max_iter=5000,penalty='l1', solver='saga') 
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print('Accuracy: ', accuracy_score(y_test, y_pred))
    print('R2 score: ', r2_score(y_test, y_pred))

# %%
run_logistic(X_train_rfc, X_test_rfc, y_train, y_test)
# Out:
# C:\Users\gsikha\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# Accuracy:  0.9649122807017544
# R2 score:  0.8492063492063492

# %%
run_logistic(X_train, X_test, y_train, y_test)
# Out:
# C:\Users\gsikha\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# Accuracy:  0.9649122807017544
# R2 score:  0.8492063492063492

# %%
# Adaboost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
xgb.fit(X_train, y_train)
# Out:
# [17:25:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/smadhu/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/smadhu/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ...

# %%
y_pred_xgb = xgb.predict(X_test)

# %%
r2_xgb, acc_score_xgb = perf_metrics(y_pred_xgb)

# %%
r2_xgb
# Out:
# 0.9246031746031746

# %%
acc_score_xgb
# Out:
# 0.9824561403508771

# %%
confusion_matrix(y_test, y_pred_xgb)
# Out:
# array([[107,   1],
#        [  2,  61]])

# %% [markdown]
# # Conclusion:
#
# | Model                              | Accuracy | R2 score |
# |:----------------------------------:|:--------:|:--------:|
# | Logistic Regression      | 96.5    | 0.85    |
# | Logistic Regression (Grid Search)     | 97.1    | 0.87    |
# | Logistic Regression with PCA transformed data     | 97.1    | 0.87    |
# | **Logistic Regression with PCA transformed data (Grid Search)**    | **98.8**    | **0.95**    |
# | Recursive Feature Elimination (RFE)    | 96.5    | 0.85    |
# | Adaboost    | 98.2    | 0.925    |

# %% [markdown]
# ### Logistic Regression with different variants were experiemented to find whether a patient belongs to benign or malignant.
#
# ### It can be observed that when input data is transformed using PCA (30 features down to 6) and given as input to Logistic Regression and fine-tuned for different combinations of hyper-parameters, an accuracy of 98.8% and R2 score of 0.95 are achieved.
